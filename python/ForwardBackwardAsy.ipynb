# %%
import uproot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# %%
cm = 3
mN1 = 1
mN1_str = ''.join(str(mN1).split('.'))

i_file = uproot.open(f'../features/signal_reco_E-{cm}TeV_N-{mN1_str}TeV.root')
s_file = uproot.open(f'../features/signal_schannel_reco_E-{cm}TeV_N-{mN1_str}TeV.root')
t_file = uproot.open(f'../features/signal_tchannel_reco_E-{cm}TeV_N-{mN1_str}TeV.root')
b_file = uproot.open(f'../features/background_reco_E-{cm}TeV.root')

# %%
df_i = pd.DataFrame(np.array(i_file['t']['features'].array()))
df_s = pd.DataFrame(np.array(s_file['t']['features'].array()))
df_t = pd.DataFrame(np.array(t_file['t']['features'].array()))
df_b = pd.DataFrame(np.array(b_file['t']['features'].array()))

df_i['target']=9
df_s['target']=1
df_t['target']=2
df_b['target']=0

df = pd.concat([df_s, df_t, df_b])
dfI = pd.concat([df_i, df_b])
df_o = df.copy()
dfI_o = dfI.copy()

df_i_o = df_i.copy()
df_s_o = df_s.copy()
df_t_o = df_t.copy()
df_b_o = df_b.copy()

# %%
plt.figure(figsize=(6.5,5))


plt.hist(df_t_o[df_t_o.chargeLepTrue == -1]['etaNTrue'], range=[-7,7], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^-$');
plt.hist(df_t_o[df_t_o.chargeLepTrue == 1]['etaNTrue'], range=[-7,7], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^+$');
plt.axvline(0)

plt.legend()

plt.title(r't-channel truth level $\eta(N)$');
plt.ylabel('A.U.');
plt.xlabel(r'$\eta(N)$');

# %%
plt.figure(figsize=(6.5,5))

plt.hist(df_s_o[df_s_o.chargeLepTrue == -1]['etaNTrue'], range=[-7,7], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^-$');
plt.hist(df_s_o[df_s_o.chargeLepTrue == 1]['etaNTrue'], range=[-7,7], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^+$');
plt.axvline(0)

plt.legend()

plt.title(r's-channel truth level $\eta(N)$');
plt.ylabel('A.U.');
plt.xlabel(r'$\eta(N)$');

# %%
plt.figure(figsize=(13,5))


ax1 = plt.subplot(121)

ax1.hist(df_t_o[df_t_o.chargeLepTrue == -1]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^-$');
ax1.hist(df_t_o[df_t_o.chargeLepTrue == 1]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^+$');
ax1.axvline(0)

ax1.legend()

ax1.set_title('t-channel truth level $\eta(\ell)$');
ax1.set_ylabel('A.U.');
ax1.set_xlabel(r'$\eta(\ell)$');



ax2 = plt.subplot(122)

ax2.hist(df_t_o[df_t_o.chargeLepTrue == -1]['etaJJTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^-$');
ax2.hist(df_t_o[df_t_o.chargeLepTrue == 1]['etaJJTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^+$');
ax2.axvline(0)

ax2.legend()

ax2.set_title('t-channel truth level $\eta(W$ Jet$)$');
ax2.set_ylabel('A.U.');
ax2.set_xlabel(r'$\eta(W$ Jet$)$');

# %%
plt.figure(figsize=(13,5))


ax1 = plt.subplot(121)

ax1.hist(df_s_o[df_s_o.chargeLepTrue == -1]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^-$');
ax1.hist(df_s_o[df_s_o.chargeLepTrue == 1]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^+$');
ax1.axvline(0)

ax1.legend()

ax1.set_title('s-channel truth level $\eta(\ell)$');
ax1.set_ylabel('A.U.');
ax1.set_xlabel(r'$\eta(\ell)$');



ax2 = plt.subplot(122)

ax2.hist(df_s_o[df_s_o.chargeLepTrue == -1]['etaJJTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^-$');
ax2.hist(df_s_o[df_s_o.chargeLepTrue == 1]['etaJJTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^+$');
ax2.axvline(0)

ax2.legend()

ax2.set_title('s-channel truth level $\eta(W$ Jet$)$');
ax2.set_ylabel('A.U.');
ax2.set_xlabel(r'$\eta(W$ Jet$)$');

# %%
plt.figure(figsize=(13,5))


ax1 = plt.subplot(121)

ax1.hist(df_t_o[(df_t_o.chargeLepTrue == -1) & (df_t_o.typeLep == 11)]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$e^-$');
ax1.hist(df_t_o[(df_t_o.chargeLepTrue == -1) & (df_t_o.typeLep == 13)]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\mu^-$');
ax1.axvline(0)

ax1.legend()
ax1.set_xlabel(r'$\eta(\ell)$')
ax1.set_title(r't-channel truth level $\eta(\ell)$');
ax1.set_ylabel('A.U.')


ax2 = plt.subplot(122)

ax2.hist(df_t_o[(df_t_o.chargeLepTrue == 1) & (df_t_o.typeLep == 11)]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$e^+$');
ax2.hist(df_t_o[(df_t_o.chargeLepTrue == 1) & (df_t_o.typeLep == 13)]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\mu^+$');
ax2.axvline(0)

ax2.legend()
ax2.set_xlabel(r'$\eta(\ell)$')
ax2.set_title(r't-channel truth level $\eta(\ell)$');
ax2.set_ylabel('A.U.')
# Out:
# Text(0, 0.5, 'A.U.')

# %%
plt.figure(figsize=(6.5,5))

plt.hist(df_t_o[(df_t_o.chargeLepTrue == -1) & (df_t_o.etaNTrue > 0)]['ELepTrue'], range=[-3,1800], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^-$');
plt.hist(df_t_o[(df_t_o.chargeLepTrue == 1) & (df_t_o.etaNTrue > 0)]['ELepTrue'], range=[-3,1800], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^+$');
# plt.axvline(0)

plt.legend()
# plt.title(r'$\eta(N)>0$');
plt.title(r't-channel $E(\ell)$ of $\eta(N)>0$');
plt.xlabel(r'$E(\ell)$ [GeV]');
plt.ylabel(r'$A.U.$');

# %%
plt.figure(figsize=(6.5,5))

plt.hist(df_s_o[(df_s_o.chargeLepTrue == -1) & (df_s_o.etaNTrue > 0)]['ELepTrue'], range=[-3,1800], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^-$');
plt.hist(df_s_o[(df_s_o.chargeLepTrue == 1) & (df_s_o.etaNTrue > 0)]['ELepTrue'], range=[-3,1800], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^+$');
# plt.axvline(0)

plt.legend()
# plt.title(r'$\eta(N)>0$');
plt.title(r's-channel $E(\ell)$ of $\eta(N)>0$');
plt.xlabel(r'$E(\ell)$ [GeV]');
plt.ylabel(r'$A.U.$');

# %%
plt.figure(figsize=(6.5,5))

plt.hist(df_t_o[(df_t_o.chargeLepTrue == -1) & (df_t_o.etaNTrue > 0)]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^-$');
plt.hist(df_t_o[(df_t_o.chargeLepTrue == 1) & (df_t_o.etaNTrue > 0)]['etaLepTrue'], range=[-3,3], bins=20, histtype='step', alpha=0.5, lw=3, label=r'$\ell^+$');
plt.axvline(0)

plt.legend()

plt.title(r't-channel $\eta(\ell)$ of $\eta(N)>0$');
plt.xlabel(r'$\eta(\ell)$');
plt.ylabel(r'$A.U.$');

# %%
len(df_s[df_s['typeLep']==11])/len(df_s[df_s['typeLep']==13])
# Out:
# 0.9374205844980941

# %%
len(df_t[df_t['typeLep']==11])/len(df_t[df_t['typeLep']==13])
# Out:
# 0.978441127694859
